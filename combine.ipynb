# %%
import pandas as pd
import numpy as np

from tqdm import tqdm
import warnings
warnings.filterwarnings("ignore")

# %%
datas = []

# %%
datas.append(pd.read_csv('part_1.csv'))
datas.append(pd.read_csv('part_2.csv'))
datas.append(pd.read_csv('part_3.csv'))
datas.append(pd.read_csv('part_4a.csv'))
datas.append(pd.read_csv('part_4b.csv'))
datas.append(pd.read_csv('part_5.csv'))

# %%
alldata = pd.concat(datas, 0)

# %%
alldata
# Out:
#          Unnamed: 0    zip NAICS.id  \
# 0                 1   6001    44-45
# 1                 2   6001    44-45
# 2                 3   6001    44-45
# 3                 4   6001    44-45
# 4                 5   6001    44-45
# 5                 6   6001    44-45
# 6                 7   6001    44-45
# 7                 8   6001      441
# 8                 9   6001      441
# 9                10   6001      441
# 10               11   6001     4411
# 11               12   6001     4411
# 12               13   6001     4411
# 13               14   6001    44111
# 14               15   6001    44111
# 15               16   6001    44111
# 16               17   6001   441110
# 17               18   6001   441110
# 18               19   6001   441110
# 19               20   6001     4413
# 20               21   6001     4413
# 21               22   6001     4413
# 22               23   6001    44132
# 23               24   6001    44132
# 24               25   6001    44132
# ...

# %%
alldata[alldata['City Name'] == 'Hartford']
# Out:
#         Unnamed: 0    zip NAICS.id                    NAICS.display-label  \
# 12007        12008   6101    44-45                           Retail trade
# 12008        12009   6101    44-45                           Retail trade
# 12009        12010   6101    44-45                           Retail trade
# 12010        12011   6101      442  Furniture and home furnishings stores
# 12011        12012   6101      442  Furniture and home furnishings stores
# 12012        12013   6101      442  Furniture and home furnishings stores
# 12013        12014   6101     4421                       Furniture stores
# 12014        12015   6101     4421                       Furniture stores
# 12015        12016   6101     4421                       Furniture stores
# 12016        12017   6101    44211                       Furniture stores
# 12017        12018   6101    44211                       Furniture stores
# 12018        12019   6101    44211                       Furniture stores
# ...

# %%
alldata['zip'][0]
# Out:
# 0     6001
# 0     3901
# 0     1001
# 0     2802
# 0    16601
# 0     5001
# Name: zip, dtype: int64

# %%
alldata.to_csv("alldata.csv")
