# %%
import pandas as pd
import numpy as np

from tqdm import tqdm
import warnings
warnings.filterwarnings("ignore")

# %%
data = pd.read_csv('data2.csv')

# %%
data
# Out:
#          Unnamed: 0    zip NAICS.id  \
# 0                 0   6001    44-45
# 1                 1   6001    44-45
# 2                 2   6001    44-45
# 3                 3   6001    44-45
# 4                 4   6001    44-45
# 5                 5   6001      441
# 6                 6   6001      441
# 7                 7   6001     4411
# 8                 8   6001     4411
# 9                 9   6001    44111
# 10               10   6001    44111
# 11               11   6001     4413
# 12               12   6001     4413
# 13               13   6001    44132
# 14               14   6001    44132
# 15               15   6001      442
# 16               16   6001      442
# 17               17   6001      442
# 18               18   6001      442
# 19               19   6001      442
# 20               20   6001     4421
# 21               21   6001     4421
# 22               22   6001     4421
# 23               23   6001     4422
# 24               24   6001     4422
# ...
